# %% [markdown]
# # Dask clusters
#
# (the material is based on the notebook https://github.com/jrbourbeau/hacking-dask)
#
# This notebook covers Dask's distributed clusters in detail.

# %% [markdown]
# ## Cluster overview
#
# In this section we'll discuss:
#
# 1. The different components which make up a Dask cluster
# 2. Survey different ways to launch a cluster

# %% [markdown]
# <img src="img/dask-system.png" width="600">

# %% [markdown]
# ## Dask configuration file

# %% [markdown]
# Taking full advantage of Dask sometimes requires user configuration. This might be to control logging verbosity, specify cluster configuration, provide credentials for security, or any of several other options that arise in production.
#
# Configuration is specified in one of the following ways:
#
# * YAML files in ~/.config/dask/ or /etc/dask/ or $DASK_CONFIG
#
# * Environment variables like `DASK_DISTRIBUTED__SCHEDULER__WORK_STEALING=True`
#
# * Default settings within other Dask sub-libraries
#
# On coffea-casa facility we already preconfigured everything for you, so please change configurations wisely :)

# %%
import dask

# %%
dask.config.config
# Out:
# {'distributed': {'scheduler': {'allowed-failures': 10,
#    'bandwidth': 1000000000,
#    'work-stealing': False},
#   'worker': {'memory': {'target': False,
#     'spill': False,
#     'pause': 0.8,
#     'terminate': 0.95},
#    'profile': {'interval': '1d', 'cycle': '2d', 'low-level': False}},
#   'diagnostics': {'nvml': False},
#   'version': 2,
#   'dashboard': {'link': '/user/{JUPYTERHUB_USER}/proxy/{port}/status'},
#   'admin': {'system-monitor': {'gil': {'enabled': True, 'interval': '10us'}},
#    'tick': {'limit': '5s'}},
#   'comm': {'require-encryption': True,
#    'tls': {'ciphers': None,
#     'ca-file': '/etc/cmsaf-secrets/ca.pem',
#     'scheduler': {'cert': '/etc/cmsaf-secrets/hostcert.pem',
#      'key': '/etc/cmsaf-secrets/hostcert.pem'},
#     'worker': {'key': None, 'cert': None},
#     'client': {'key': '/etc/cmsaf-secrets/hostcert.pem',
#      'cert': '/etc/cmsaf-secrets/hostcert.pem'}}}},
#  'jobqueue': {'coffea-casa': {'name': 'dask-worker',
#    'cores': 1,
#    'memory': '3GiB',
#    'processes': 1,
#    'worker-image': 'hub.opensciencegrid.org/coffea-casa/cc-analysis-alma8:2024.04.05',
#    'python': None,
#    'interface': None,
#    'death-timeout': 60,
#    'local-directory': None,
#    'shared-temp-directory': None,
#    'extra': None,
#    'worker-command': 'distributed.cli.dask_worker',
#    'worker-extra-args': [],
#    'disk': '2 GiB',
#    'env-extra': None,
#    'job-script-prologue': [],
#    'job-extra': None,
#    'job-extra-directives': {},
#    'job-directives-skip': [],
#    'submit-command-extra': ['-spool'],
#    'cancel-command-extra': [],
#    'log-directory': None,
#    'shebang': '#!/usr/bin/env condor_submit',
#    'scheduler-options': {}}},
#  'labextension': {'factory': {'module': 'coffea_casa',
#    'class': 'CoffeaCasaCluster',
#    'args': [],
#    'kwargs': {}},
#   'default': {'workers': None, 'adapt': {'minimum': 0, 'maximum': 50}},
#   'initial': [{'name': 'UNL HTCondor Cluster',
#     'workers': None,
#     'adapt': {'minimum': 0, 'maximum': 50}}]},
#  'syed_2emahedi_2ehasan_40cern_2ech_port_
40cern_2ech_port_8787_tcp_proto': 'tcp',
#  'm251890_40usna_2eedu_port_8786_tcp_port': 8786,
#  'christinagmondelli_40lewisu_2eedu_port_8788_tcp_proto': 'tcp',
#  'elmaka8700_40gmail_2ecom_port_8787_tcp_proto': 'tcp',
#  'sitian_2eqian_40cern_2ech_port_8788_tcp_port': 8788,
#  'andrzej_2enovak_40cern_2ech_port_8786_tcp_proto': 'tcp',
#  'bhora_2ey_40northeastern_2eedu_port_8786_tcp_port': 8786,
#  'austin_2eolson_40cern_2ech_port_8786_tcp_port': 8786,
#  'margaret_2emorris_40cern_2ech_port_8788_tcp_addr': '10.111.22.31',
#  'm_2ehussain_40cern_2ech_port_8788_tcp_proto': 'tcp',
#  'thomas_2evan_2elaer_40cern_2ech_service_port_dask_dashboard': 8787,
#  'kcr8wx_40virginia_2eedu_port_8788_tcp_proto': 'tcp',
#  'syed_2emahedi_2ehasan_40cern_2ech_service_port': 8786,
#  'eleanor_2em_2es_40icloud_2ecom_port_8786_tcp': 'tcp://10.99.98.57:8786',
#  'jakub_2egajownik_40cern_2ech_port_8788_tcp_port': 8788,
#  'matthew_2eedwin_2edittrich_40cern_2ech_service_host': '10.108.37.94',
#  'ali_2eeren_2esimsek_40cern_2ech_service_host': '10.96.102.49',
#  'colac_2d27_40rhodes_2eedu_port_8788_tcp_addr': '10.100.148.40',
#  'emettner_40wisc_2eedu_port_8787_tcp_port': 8787,
#  'mariarosaria_2ed_27alfonso_40cern_2ech_port_8786_tcp_proto': 'tcp',
#  'matthew_2eedwin_2edittrich_40cern_2ech_service_port': 8786,
#  'ali_2eeren_2esimsek_40cern_2ech_service_port': 8786,
#  'clundstedt_40unl_2eedu_service_port_dask_worker': 8788,
#  'colac_2d27_40rhodes_2eedu_port_8787_tcp_proto': 'tcp',
#  'clundstedt_40unl_2eedu_port_8788_tcp_port': 8788,
#  'noah_2ealexander_2ezipper_40cern_2ech_port_8788_tcp': 'tcp://10.99.180.128:8788',
#  'mariarosaria_2ed_27alfonso_40cern_2ech_port_8786_tcp_addr': '10.97.94.64',
#  'm_2ehussain_40cern_2ech_service_port_dask_worker': 8788,
#  'aashwin_2ebasnet_40cern_2ech_port_8786_tcp_addr': '10.99.184.165',
#  'derek_2eweitzel_40cern_2ech_service_port_dask_worker': 8788,
#  'yibo_2ezhong_40cern_2ech_port_8788_tcp_addr': '10.106.15.241',
#  'aashwin_2ebasnet_40cern_2ech_port_8786_tcp': 'tcp://10.99.184.165:8786',
#  'ali_2eeren_2esimsek_40cern_2ech_port': 'tcp://10.96.102.49:8786',
#  'matthew_2eedwin_2edittrich_40cern_2ech_port': 'tcp://10.108.37.94:8786',
#  'j_2ehogan_40cern_2ech_port_8787_tcp': 'tcp://10.101.130.157:8787',
#  'haifa_2erejeb_2esfar_40cern_2ech_port_8788_tcp': 'tcp://10.110.59.216:8788',
#  'syed_2emahedi_2ehasan_40cern_2ech_service_port_dask_scheduler': 8786,
#  'm261524_40usna_2eedu_port_8788_tcp_addr': '10.96.150.110',
#  'brian_2ebockelman_40cern_2ech_port_8787_tcp_addr': '10.103.188.126',
#  'j_2ehogan_40cern_2ech_service_port_dask_dashboard': 8787,
#  'zhenyu_2ewu_40cern_2ech_port_8787_tcp_port': 8787,
#  'm251890_40usna_2eedu_service_port': 8786,
#  'j_2ehogan_40cern_2ech_port_8786_tcp': 'tcp://10.101.130.157:8786',
#  'mattia_2ecampana_40cern_2ech_service_port_dask_worker': 8788,
40cern_2ech_port_8786_tcp_proto': 'tcp',
#  'bouchamaouihichem_40gmail_2ecom_port_8787_tcp_port': 8787,
#  'haifa_2erejeb_2esfar_40cern_2ech_port': 'tcp://10.110.59.216:8786',
#  'yibo_2ezhong_40cern_2ech_service_port_dask_worker': 8788,
#  'noah_2ealexander_2ezipper_40cern_2ech_port_8788_tcp_port': 8788,
#  'm261524_40usna_2eedu_service_port_dask_dashboard': 8787,
#  'margaret_2emorris_40cern_2ech_port_8786_tcp_proto': 'tcp',
#  'cebarros_40buffalo_2eedu_port_8787_tcp_port': 8787,
#  'ianna_2eosborne_40cern_2ech_port_8787_tcp_addr': '10.104.228.92',
#  'emmanuel_2ebotero_2eosorio_40cern_2ech_port_8786_tcp_addr': '10.100.105.233',
#  'thomas_2evan_2elaer_40cern_2ech_port_8786_tcp_addr': '10.105.255.87',
#  'yibo_2ezhong_40cern_2ech_port_8788_tcp_proto': 'tcp',
#  'yibo_2ezhong_40cern_2ech_port': 'tcp://10.106.15.241:8786',
#  'sitian_2eqian_40cern_2ech_port_8786_tcp_proto': 'tcp',
#  'zhenyu_2ewu_40cern_2ech_service_port': 8786,
#  'nicholas_2ejames_2emanganelli_40cern_2ech_service_port_dask_dashboard': 8787,
#  'sai_2eneha_2esantpur_40cern_2ech_service_port_dask_scheduler': 8786,
#  'andrzej_2enovak_40cern_2ech_port_8786_tcp_port': 8786,
#  'jakub_2egajownik_40cern_2ech_port_8787_tcp': 'tcp://10.110.99.186:8787',
#  'nicholas_2ejames_2emanganelli_40cern_2ech_service_host': '10.104.97.20',
#  'margaret_2emorris_40cern_2ech_service_port': 8786,
#  'm_2ehussain_40cern_2ech_port_8786_tcp': 'tcp://10.106.210.183:8786',
#  'zhiyuan_2ehuang_40cern_2ech_port_8787_tcp': 'tcp://10.102.234.249:8787',
#  'elmaka8700_40gmail_2ecom_service_port_dask_scheduler': 8786,
#  'elmaka8700_40gmail_2ecom_service_host': '10.110.40.229',
#  'bouchamaouihichem_40gmail_2ecom_port_8788_tcp_addr': '10.98.63.29',
#  'cebarros_40buffalo_2eedu_port_8786_tcp': 'tcp://10.108.151.198:8786',
#  'm251890_40usna_2eedu_port_8786_tcp_proto': 'tcp',
#  'andrzej_2enovak_40cern_2ech_port_8788_tcp': 'tcp://10.96.243.51:8788',
#  'emettner_40wisc_2eedu_port': 'tcp://10.106.111.65:8786',
#  'clundstedt_40unl_2eedu_port_8786_tcp_proto': 'tcp',
#  'oksana_2eshadura_40cern_2ech_port_8787_tcp_proto': 'tcp',
#  'sai_2eneha_2esantpur_40cern_2ech_port_8786_tcp_addr': '10.101.234.95',
#  'arualesb_2e1_40cern_2ech_service_port_dask_scheduler': 8786,
#  'andrzej_2enovak_40cern_2ech_port_8788_tcp_proto': 'tcp',
#  'elmaka8700_40gmail_2ecom_port_8788_tcp_port': 8788,
#  'ashling_2equinn_40cern_2ech_port_8788_tcp_addr': '10.109.148.158',
#  'mohammad_2esahraei_40cern_2ech_port': 'tcp://10.108.97.198:8786',
#  'bhora_2ey_40northeastern_2eedu_port_8786_tcp_proto': 'tcp',
#  'dg669_40cornell_2eedu_service_port_dask_scheduler': 8786,
#  'austin_2eolson_40cern_2ech_port_8786_tcp_proto': 'tcp',
#  'haifa_2erejeb_2esfar_40cern_2ech_port_8786_tcp_addr': '10.110.59.216',
#  'mattia_2ecampana_40cern_2ech_port_8788_tcp_port': 8788,
#  'sai_2eneha_2esantpur_40cern_2ech_port_8788_tcp_addr': '10.101.234.95',
#  'm_2ehussain_40cern_2ech_port_8787_tcp_port': 8787,
#  'haifa_2erejeb_2esfar_40cern_2ech_port_8787_tcp_proto': 'tcp',
#  'haifa_2erejeb_2esfar_40cern_2ech_port_8786_tcp_port': 8786,
#  'mohammad_2esahraei_40cern_2ech_service_port_dask_scheduler': 8786,
#  'elmaka8700_40gmail_2ecom_port_8788_tcp_proto': 'tcp',
#  'itzelli_2esalazar_2esegovia_40cern_2ech_service_host': '10.108.194.72',
#  'dg669_40cornell_2eedu_port_8788_tcp': 'tcp://10.102.158.117:8788',
#  'austin_2eolson_40cern_2ech_service_port': 8786,
#  'bhora_2ey_40northeastern_2eedu_service_port': 8786,
#  'clundstedt_40unl_2eedu_service_port_dask_scheduler': 8786,
#  'zhenyu_2ewu_40cern_2ech_port_8787_tcp': 'tcp://10.111.204.7:8787',
#  'kcr8wx_40virginia_2eedu_port_8788_tcp_addr': '10.99.170.112',
#  'alheld_port_8786_tcp_proto': 'tcp',
#  'margaret_2emorris_40cern_2ech_port_8788_tcp': 'tcp://10.111.22.31:8788',
#  'lindsey_2egray_40cern_2ech_port_8786_tcp_addr': '10.104.200.151',
#  'derek_2eweitzel_40cern_2ech_port': 'tcp://10.104.235.152:8786',
#  'ianna_2eosborne_40cern_2ech_service_port_dask_scheduler': 8786,
#  'aashwin_2ebasnet_40cern_2ech_port_8786_tcp_port': 8786,
#  'm251890_40usna_2eedu_port_8786_tcp_addr': '10.109.129.254',
#  'temporary-directory': None,
#  'visualization': {'engine': None},
#  'tokenize': {'ensure-deterministic': False},
#  'dataframe': {'backend': 'pandas',
#   'shuffle': {'method': None, 'compression': None},
#   'parquet': {'metadata-task-size-local': 512, 'metadata-task-size-remote': 1},
#   'convert-string': None,
#   'query-planning': None},
#  'array': {'backend': 'numpy',
#   'chunk-size': '128MiB',
#   'rechunk': {'method': 'tasks', 'threshold': 4},
#   'svg': {'size': 120},
#   'slicing': {'split-large-chunks': None}},
#  'optimization': {'annotations': {'fuse': True},
#   'fuse': {'active': None,
#    'ave-width': 1,
#    'max-width': None,
#    'max-height': inf,
#    'max-depth-new-edges': None,
#    'subgraphs': None,
#    'rename-keys': True}},
#  'admin': {'traceback': {'shorten': ['concurrent[\\\\\\/]futures[\\\\\\/]',
#     'dask[\\\\\\/](base|core|local|multiprocessing|optimization|threaded|utils)\\.py',
#     'dask[\\\\\\/]array[\\\\\\/]core\\.py',
#     'dask[\\\\\\/]dataframe[\\\\\\/](core|methods)\\.py',
#     'distributed[\\\\\\/](client|scheduler|utils|worker)\\.py',
#     'tornado[\\\\\\/]gen\\.py',
#     'pandas[\\\\\\/]core[\\\\\\/]']}}}

# %%
dask.config.get("distributed.comm.require-encryption")
# Out:
# True

# %%
#dask.config.set({'distributed.comm.require-encryption': False})

# %%
#dask.config.get("distributed.comm.require-encryption")

# %% [markdown]
# ### Components of a cluster
#
# A Dask cluster is composed of three different types of objects:
#
# 1. **Scheduler**: A single, centralized scheduler process which responds to requests for computations, maintains relavant state about tasks and worker, and sends tasks to workers to be computed.
# 2. **Workers**: One or more worker processes which compute tasks and store/serve their results.
# 3. **Clients**: One or more client objects which are the user-facing entry point to interact with the cluster.
#
# A couple of notes about workers:
#
# - Each worker runs in its own Python process. Each worker Python process has its own `concurrent.futures.ThreadPoolExecutor` which is uses to compute tasks in parallel.
# - There's actually a fourth cluster object which is often not discussed: the **Nanny**. By default Dask workers are launched and managed by a separate nanny process. This separate process allows workers to restart themselves if you want to use the `Client.restart` method, or to restart workers automatically if they get above a certain memory limit threshold.

# %% [markdown]
# <img src="img/dask-cluster.svg" width="600">

# %% [markdown]
# #### Related Documentation
#
# - [Cluster architecture](https://distributed.dask.org/en/latest/#architecture)
# - [Journey of a task](https://distributed.dask.org/en/latest/journey.html)
#
# ## Deploying Dask clusters
#
# Deploying a Dask cluster means launching scheduler, worker, and client processes and setting up the appropriate network connections so these processes can communicate with one another. Dask clusters can be lauched in a few different ways which we will discuss later.

# %% [markdown]
# ## Cluster managers

# %% [markdown]
# Dask has the notion of cluster manager objects. Cluster managers offer a consistent interface for common activities like adding/removing workers to a cluster, retrieving logs, etc.

# %% [markdown]
# <img src="img/dask-cluster-manager.svg" width="600">

# %% [markdown]
# ### Dask LocalCluster cluster manager
#
# LocalCluster creates a "cluster" of a scheduler and workers running on the local machine.
#
# Creating a cluster object will create a Dask scheduler and a number of Dask workers. If no arguments are specified then it will autodetect the number of CPU cores your system has and the amount of memory and create workers to appropriately fill that. You can also specify these arguments yourself.

# %% [markdown]
# You can create a dask.distributed scheduler by importing and creating a Client with no arguments. This overrides whatever default was previously set.

# %%
#from dask.distributed import Client
#client = Client()

# %%
#client.close()

# %% [markdown]
# Dask works well at many scales ranging from a single machine to clusters of many machines. In our case we provide each user already preconfigured resource ready to be scale.

# %% [markdown]
# ### Dask-jobqueue library
#
# The Dask-jobqueue project makes it easy to deploy Dask on common job queuing systems typically found in high performance supercomputers, academic research institutions, and other clusters. It provides a convenient interface that is accessible from interactive systems like Jupyter notebooks, or batch jobs.
#
# Launching clusters will follows a similar pattern as using Dask's built-in `LocalCluster`:
#
# ```python
#
# # Launch a Dask cluster on a HTCondor job queueing system [For this you will need HTCondor related configurations]
# from dask_jobqueue import HTCondorCluster
# cluster = HTCondorCluster(...)
#
#
# # Launch a Dask cluster on a SLURM job queueing system [For this you will need SLURM related configurations]
# from dask_jobqueue import SLURMCluster
# cluster = SLURMCluster(...)
#
#
# # Launch a Dask cluster on a PBS job queueing system [For this you will need PBS related configurations]
# from dask_jobqueue import PBSCluster
# cluster = PBSCluster(...)
#
#
# # Launch a Dask cluster on a Kubernetes cluster [For this you will need Kubernetes related configurations]
# from dask_kubernetes import KubeCluster
# cluster = KubeCluster(...)
#
# ```

# %% [markdown]
# ### CoffeaCasaCluster cluster manager
#
# The "scale out" process at Coffea-Casa Analysis Facility is accomplished by using custom dask-jobqueue class that helps easily deploy Dask worker over UNL Tier-2 HTCondor batch queue or Kubernetes cluster available at UNL.

# %% [markdown]
# The dask Client is the primary entry point for users of `dask.distributed`.
#
# We pre-configured a Dask cluster for you automatically, and you just need to initialize a Client by pointing it to the address of a Scheduler (in coffea-casa it is always `tls://localhost:8786`):

# %%
from dask.distributed import Client

client = Client("tls://localhost:8786")
client
